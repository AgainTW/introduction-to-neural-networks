# %% [markdown]
# # Import packages

# %%
import math
import cv2
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from tensorflow import Tensor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, Flatten, Dense, Dropout

# %matplotlib inline

# %% [markdown]
# # Load dataset

# %%
from keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.reshape(-1, 32, 32, 3)
y_train = tf.keras.utils.to_categorical(y_train, 10)

x_test = x_test.reshape(-1, 32, 32, 3)
y_test = tf.keras.utils.to_categorical(y_test, 10)

print(f"shape of train image: {x_train.shape}")
print(f"shape of train label: {y_train.shape}")
print(f"shape of test image: {x_test.shape}")
print(f"shape of train label: {y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 17s 0us/step
# shape of train image: (50000, 32, 32, 3)
# shape of train label: (50000, 10)
# shape of test image: (10000, 32, 32, 3)
# shape of train label: (10000, 10)

# %%
fig, ax = plt.subplots(1, 2, sharey=True, figsize=(24, 8))
fig.suptitle('Distribution of data')

sns.countplot(ax=ax[0], x=np.argmax(y_train, axis=1)) 
ax[0].set_title('Train')
ax[0].set_ylabel('Samples')

sns.countplot(ax=ax[1], x=np.argmax(y_test, axis=1)) 
ax[1].set_title('Test')
ax[1].set_ylabel('Samples')

plt.show()

# %% [markdown]
# # early_stopping

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=30, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# %% [markdown]
# # AlexNet

# %%
def get_AlexNet(input_shape, output_shape):
  inputs = tf.keras.Input(shape=input_shape, name='input_layer')

  x = tf.keras.layers.Conv2D(96/8, (math.ceil(11/3), math.ceil(11/3)), strides=(math.ceil(4/2), math.ceil(4/2)), activation='relu', name="conv_layer_1")(inputs)
  x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name="pooling_layer_1")(x)

  x = tf.keras.layers.Conv2D(256/8, (5, 5), strides=(1, 1), padding='same', activation='relu', name="conv_layer_2")(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name="pooling_layer_2")(x)

  x = tf.keras.layers.Conv2D(384/8, (3, 3), strides=(1, 1), padding='same', activation='relu', name="conv_layer_3")(x)
  x = tf.keras.layers.Conv2D(384/8, (3, 3), strides=(1, 1), padding='same', activation='relu', name="conv_layer_4")(x)
  x = tf.keras.layers.Conv2D(256/8, (3, 3), strides=(1, 1), padding='same', activation='relu', name="conv_layer_5")(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name="pooling_layer_3")(x)

  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dense(4096/32, activation="relu", name='Dense_layer_1')(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  x = tf.keras.layers.Dense(4096/32, activation="relu", name='Dense_layer_2')(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  outputs = tf.keras.layers.Dense(output_shape, activation="relu", name='softmax')(x)

  model = tf.keras.Model(inputs=inputs, outputs=outputs, name="functional_api")
  return model

# %%
AlexNet = get_AlexNet((32,32,3), 10)
AlexNet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=tf.keras.losses.MSE, metrics=['accuracy'])
AlexNet.summary()
# Out:
# Model: "functional_api"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 32, 32, 3)]       0
#
#  conv_layer_1 (Conv2D)       (None, 15, 15, 12)        588
#
#  pooling_layer_1 (MaxPooling  (None, 7, 7, 12)         0
#  2D)
#
#  conv_layer_2 (Conv2D)       (None, 7, 7, 32)          9632
#
#  pooling_layer_2 (MaxPooling  (None, 3, 3, 32)         0
#  2D)
#
#  conv_layer_3 (Conv2D)       (None, 3, 3, 48)          13872
#
#  conv_layer_4 (Conv2D)       (None, 3, 3, 48)          20784
#
#  conv_layer_5 (Conv2D)       (None, 3, 3, 32)          13856
#
#  pooling_layer_3 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  flatten_5 (Flatten)         (None, 32)                0
#
#  Dense_layer_1 (Dense)       (None, 128)               4224
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  Dense_layer_2 (Dense)       (None, 128)               16512
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  softmax (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 80,758
# Trainable params: 80,758
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(AlexNet, to_file="my_model.png", show_shapes=True)

# %%
history = AlexNet.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=128,
    epochs=100,
    callbacks=[early_stopping], # put your callbacks in a list
)
# Out:
# Epoch 1/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.3030 - accuracy: 0.1133 - val_loss: 0.0934 - val_accuracy: 0.1873
# Epoch 2/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0893 - accuracy: 0.1990 - val_loss: 0.0822 - val_accuracy: 0.2602
# Epoch 3/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0832 - accuracy: 0.2707 - val_loss: 0.0782 - val_accuracy: 0.3368
# Epoch 4/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0801 - accuracy: 0.3175 - val_loss: 0.0765 - val_accuracy: 0.3581
# Epoch 5/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0780 - accuracy: 0.3496 - val_loss: 0.0736 - val_accuracy: 0.4011
# Epoch 6/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0759 - accuracy: 0.3818 - val_loss: 0.0718 - val_accuracy: 0.4257
# Epoch 7/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0738 - accuracy: 0.4114 - val_loss: 0.0702 - val_accuracy: 0.4493
# Epoch 8/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0719 - accuracy: 0.4343 - val_loss: 0.0681 - val_accuracy: 0.4632
# Epoch 9/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0701 - accuracy: 0.4534 - val_loss: 0.0666 - val_accuracy: 0.4786
# Epoch 10/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0688 - accuracy: 0.4705 - val_loss: 0.0662 - val_accuracy: 0.4709
# Epoch 11/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0670 - accuracy: 0.4885 - val_loss: 0.0644 - val_accuracy: 0.4953
# Epoch 12/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0655 - accuracy: 0.5036 - val_loss: 0.0645 - val_accuracy: 0.4947
# Epoch 13/100
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0644 - accuracy: 0.5182 - val_loss: 0.0630 - val_accuracy: 0.5141
# Epoch 14/100
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0633 - accuracy: 0.5260 - val_loss: 0.0648 - val_accuracy: 0.4950
# Epoch 15/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0627 - accuracy: 0.5321 - val_loss: 0.0623 - val_accuracy: 0.5223
# Epoch 16/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0615 - accuracy: 0.5441 - val_loss: 0.0598 - val_accuracy: 0.5470
# Epoch 17/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0608 - accuracy: 0.5515 - val_loss: 0.0624 - val_accuracy: 0.5253
# Epoch 18/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0600 - accuracy: 0.5623 - val_loss: 0.0603 - val_accuracy: 0.5498
# Epoch 19/100
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0591 - accuracy: 0.5688 - val_loss: 0.0593 - val_accuracy: 0.5543
# Epoch 20/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0585 - accuracy: 0.5756 - val_loss: 0.0576 - val_accuracy: 0.5651
# Epoch 21/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0576 - accuracy: 0.5829 - val_loss: 0.0577 - val_accuracy: 0.5697
# Epoch 22/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0569 - accuracy: 0.5905 - val_loss: 0.0576 - val_accuracy: 0.5629
# Epoch 23/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0563 - accuracy: 0.5990 - val_loss: 0.0568 - val_accuracy: 0.5810
# Epoch 24/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0554 - accuracy: 0.6049 - val_loss: 0.0599 - val_accuracy: 0.5500
# Epoch 25/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0552 - accuracy: 0.6065 - val_loss: 0.0592 - val_accuracy: 0.5654
# Epoch 26/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0541 - accuracy: 0.6156 - val_loss: 0.0590 - val_accuracy: 0.5582
# Epoch 27/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0536 - accuracy: 0.6211 - val_loss: 0.0589 - val_accuracy: 0.5660
# Epoch 28/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0526 - accuracy: 0.6292 - val_loss: 0.0589 - val_accuracy: 0.5616
# Epoch 29/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0522 - accuracy: 0.6340 - val_loss: 0.0563 - val_accuracy: 0.5926
# Epoch 30/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0522 - accuracy: 0.6321 - val_loss: 0.0549 - val_accuracy: 0.5956
# Epoch 31/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0510 - accuracy: 0.6422 - val_loss: 0.0546 - val_accuracy: 0.6036
# Epoch 32/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0513 - accuracy: 0.6438 - val_loss: 0.0547 - val_accuracy: 0.6033
# Epoch 33/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0504 - accuracy: 0.6488 - val_loss: 0.0548 - val_accuracy: 0.6061
# Epoch 34/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0493 - accuracy: 0.6592 - val_loss: 0.0540 - val_accuracy: 0.6061
# Epoch 35/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0492 - accuracy: 0.6593 - val_loss: 0.0557 - val_accuracy: 0.5928
# Epoch 36/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0491 - accuracy: 0.6604 - val_loss: 0.0555 - val_accuracy: 0.5986
# Epoch 37/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0484 - accuracy: 0.6655 - val_loss: 0.0547 - val_accuracy: 0.6027
# Epoch 38/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0483 - accuracy: 0.6664 - val_loss: 0.0566 - val_accuracy: 0.5915
# Epoch 39/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0477 - accuracy: 0.6732 - val_loss: 0.0538 - val_accuracy: 0.6110
# Epoch 40/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0470 - accuracy: 0.6775 - val_loss: 0.0542 - val_accuracy: 0.6115
# Epoch 41/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0461 - accuracy: 0.6837 - val_loss: 0.0540 - val_accuracy: 0.6105
# Epoch 42/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0462 - accuracy: 0.6833 - val_loss: 0.0536 - val_accuracy: 0.6110
# Epoch 43/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0460 - accuracy: 0.6861 - val_loss: 0.0529 - val_accuracy: 0.6190
# Epoch 44/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0450 - accuracy: 0.6932 - val_loss: 0.0526 - val_accuracy: 0.6251
# Epoch 45/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0455 - accuracy: 0.6899 - val_loss: 0.0541 - val_accuracy: 0.6170
# Epoch 46/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0443 - accuracy: 0.6980 - val_loss: 0.0543 - val_accuracy: 0.6103
# Epoch 47/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0446 - accuracy: 0.6977 - val_loss: 0.0528 - val_accuracy: 0.6269
# Epoch 48/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0445 - accuracy: 0.6990 - val_loss: 0.0540 - val_accuracy: 0.6201
# Epoch 49/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0433 - accuracy: 0.7066 - val_loss: 0.0534 - val_accuracy: 0.6187
# Epoch 50/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0439 - accuracy: 0.7021 - val_loss: 0.0524 - val_accuracy: 0.6219
# Epoch 51/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0432 - accuracy: 0.7079 - val_loss: 0.0537 - val_accuracy: 0.6216
# Epoch 52/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0437 - accuracy: 0.7046 - val_loss: 0.0546 - val_accuracy: 0.6114
# Epoch 53/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0425 - accuracy: 0.7151 - val_loss: 0.0541 - val_accuracy: 0.6146
# Epoch 54/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0422 - accuracy: 0.7166 - val_loss: 0.0542 - val_accuracy: 0.6189
# Epoch 55/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0424 - accuracy: 0.7151 - val_loss: 0.0559 - val_accuracy: 0.6094
# Epoch 56/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0423 - accuracy: 0.7175 - val_loss: 0.0543 - val_accuracy: 0.6159
# Epoch 57/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0420 - accuracy: 0.7186 - val_loss: 0.0533 - val_accuracy: 0.6227
# Epoch 58/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0415 - accuracy: 0.7228 - val_loss: 0.0535 - val_accuracy: 0.6188
# Epoch 59/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0411 - accuracy: 0.7258 - val_loss: 0.0532 - val_accuracy: 0.6253
# Epoch 60/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0413 - accuracy: 0.7237 - val_loss: 0.0549 - val_accuracy: 0.6162
# Epoch 61/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0408 - accuracy: 0.7273 - val_loss: 0.0552 - val_accuracy: 0.6104
# Epoch 62/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0410 - accuracy: 0.7257 - val_loss: 0.0555 - val_accuracy: 0.6107
# Epoch 63/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0402 - accuracy: 0.7338 - val_loss: 0.0546 - val_accuracy: 0.6217
# Epoch 64/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0408 - accuracy: 0.7287 - val_loss: 0.0549 - val_accuracy: 0.6177
# Epoch 65/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0400 - accuracy: 0.7355 - val_loss: 0.0550 - val_accuracy: 0.6183
# Epoch 66/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0398 - accuracy: 0.7367 - val_loss: 0.0553 - val_accuracy: 0.6149
# Epoch 67/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0396 - accuracy: 0.7389 - val_loss: 0.0532 - val_accuracy: 0.6302
# Epoch 68/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0393 - accuracy: 0.7403 - val_loss: 0.0538 - val_accuracy: 0.6278
# Epoch 69/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0410 - accuracy: 0.7286 - val_loss: 0.0543 - val_accuracy: 0.6257
# Epoch 70/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0395 - accuracy: 0.7392 - val_loss: 0.0538 - val_accuracy: 0.6281
# Epoch 71/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0387 - accuracy: 0.7448 - val_loss: 0.0555 - val_accuracy: 0.6174
# Epoch 72/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0384 - accuracy: 0.7483 - val_loss: 0.0545 - val_accuracy: 0.6258
# Epoch 73/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0389 - accuracy: 0.7450 - val_loss: 0.0544 - val_accuracy: 0.6247
# Epoch 74/100
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0385 - accuracy: 0.7487 - val_loss: 0.0552 - val_accuracy: 0.6177

# %%
AlexNet.save("cifar10_AlexNet.h5")

# %%
# Loss
fig, ax = plt.subplots(figsize=(8,4))
plt.title('loss')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss', linestyle='--')
plt.legend()
plt.show()

# Accuracy
fig, ax = plt.subplots(figsize=(8,4))
plt.title('accuracy')
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy', linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# # VGG

# %%
def get_VGG(input_shape, output_shape):
  c = 8
  inputs = tf.keras.Input(shape=input_shape, name='input_layer')

  x = tf.keras.layers.Conv2D(64/c, (3, 3), padding='same', activation='relu', name="conv_layer_1")(inputs)
  x = tf.keras.layers.Conv2D(64/c, (3, 3), padding='same', activation='relu', name="conv_layer_2")(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name="pooling_layer_1")(x)

  x = tf.keras.layers.Conv2D(128/c, (3, 3), padding='same', activation='relu', name="conv_layer_3")(x)
  x = tf.keras.layers.Conv2D(128/c, (3, 3), padding='same', activation='relu', name="conv_layer_4")(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name="pooling_layer_2")(x)

  x = tf.keras.layers.Conv2D(256/c, (3, 3), padding='same', activation='relu', name="conv_layer_5")(x)
  x = tf.keras.layers.Conv2D(256/c, (3, 3), padding='same', activation='relu', name="conv_layer_6")(x)
  x = tf.keras.layers.Conv2D(256/c, (3, 3), padding='same', activation='relu', name="conv_layer_7")(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name="pooling_layer_3")(x)  

  x = tf.keras.layers.Conv2D(512/c, (3, 3), padding='same', activation='relu', name="conv_layer_8")(x)
  x = tf.keras.layers.Conv2D(512/c, (3, 3), padding='same', activation='relu', name="conv_layer_9")(x)
  x = tf.keras.layers.Conv2D(512/c, (3, 3), padding='same', activation='relu', name="conv_layer_10")(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name="pooling_layer_4")(x)

  x = tf.keras.layers.Conv2D(512/c, (3, 3), padding='same', activation='relu', name="conv_layer_11")(x)
  x = tf.keras.layers.Conv2D(512/c, (3, 3), padding='same', activation='relu', name="conv_layer_12")(x)
  x = tf.keras.layers.Conv2D(512/c, (3, 3), padding='same', activation='relu', name="conv_layer_13")(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name="pooling_layer_5")(x)  

  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dense(4096/c, activation="relu", name='Dense_layer_1')(x)
  x = tf.keras.layers.Dense(4096/c, activation="relu", name='Dense_layer_2')(x)
  outputs = tf.keras.layers.Dense(output_shape, activation="relu", name='softmax')(x)

  model = tf.keras.Model(inputs=inputs, outputs=outputs, name="functional_api")
  return model

# %%
VGG = get_VGG((32,32,3), 10)
VGG.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=tf.keras.losses.MSE, metrics=['accuracy'])
VGG.summary()
# Out:
# Model: "functional_api"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 32, 32, 3)]       0
#
#  conv_layer_1 (Conv2D)       (None, 32, 32, 8)         224
#
#  conv_layer_2 (Conv2D)       (None, 32, 32, 8)         584
#
#  pooling_layer_1 (MaxPooling  (None, 16, 16, 8)        0
#  2D)
#
#  conv_layer_3 (Conv2D)       (None, 16, 16, 16)        1168
#
#  conv_layer_4 (Conv2D)       (None, 16, 16, 16)        2320
#
#  pooling_layer_2 (MaxPooling  (None, 8, 8, 16)         0
#  2D)
#
#  conv_layer_5 (Conv2D)       (None, 8, 8, 32)          4640
#
#  conv_layer_6 (Conv2D)       (None, 8, 8, 32)          9248
#
#  conv_layer_7 (Conv2D)       (None, 8, 8, 32)          9248
#
#  pooling_layer_3 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  conv_layer_8 (Conv2D)       (None, 4, 4, 64)          18496
#
#  conv_layer_9 (Conv2D)       (None, 4, 4, 64)          36928
#
#  conv_layer_10 (Conv2D)      (None, 4, 4, 64)          36928
#
#  pooling_layer_4 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  conv_layer_11 (Conv2D)      (None, 2, 2, 64)          36928
#
#  conv_layer_12 (Conv2D)      (None, 2, 2, 64)          36928
#
#  conv_layer_13 (Conv2D)      (None, 2, 2, 64)          36928
#
#  pooling_layer_5 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten_7 (Flatten)         (None, 64)                0
#
#  Dense_layer_1 (Dense)       (None, 512)               33280
#
#  Dense_layer_2 (Dense)       (None, 512)               262656
#
#  softmax (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 531,634
# Trainable params: 531,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(VGG, to_file="my_model.png", show_shapes=True)

# %%
history = VGG.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=128,
    epochs=100,
    callbacks=[early_stopping], # put your callbacks in a list
)
# Out:
# Epoch 1/100
# 391/391 [==============================] - 5s 11ms/step - loss: 0.0881 - accuracy: 0.2284 - val_loss: 0.0786 - val_accuracy: 0.3520
# Epoch 2/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0754 - accuracy: 0.3903 - val_loss: 0.0733 - val_accuracy: 0.4205
# Epoch 3/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0697 - accuracy: 0.4483 - val_loss: 0.0682 - val_accuracy: 0.4642
# Epoch 4/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0658 - accuracy: 0.4835 - val_loss: 0.0660 - val_accuracy: 0.4831
# Epoch 5/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0625 - accuracy: 0.5099 - val_loss: 0.0636 - val_accuracy: 0.5054
# Epoch 6/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0561 - accuracy: 0.5706 - val_loss: 0.0564 - val_accuracy: 0.5734
# Epoch 7/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0521 - accuracy: 0.6049 - val_loss: 0.0544 - val_accuracy: 0.5864
# Epoch 8/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0503 - accuracy: 0.6191 - val_loss: 0.0541 - val_accuracy: 0.5884
# Epoch 9/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0485 - accuracy: 0.6317 - val_loss: 0.0530 - val_accuracy: 0.6016
# Epoch 10/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0469 - accuracy: 0.6472 - val_loss: 0.0544 - val_accuracy: 0.5893
# Epoch 11/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0451 - accuracy: 0.6597 - val_loss: 0.0521 - val_accuracy: 0.6028
# Epoch 12/100
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0441 - accuracy: 0.6678 - val_loss: 0.0520 - val_accuracy: 0.6081
# Epoch 13/100
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0428 - accuracy: 0.6781 - val_loss: 0.0527 - val_accuracy: 0.6012
# Epoch 14/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0417 - accuracy: 0.6872 - val_loss: 0.0525 - val_accuracy: 0.6017
# Epoch 15/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0360 - accuracy: 0.7439 - val_loss: 0.0481 - val_accuracy: 0.6546
# Epoch 16/100
# 391/391 [==============================] - 6s 15ms/step - loss: 0.0341 - accuracy: 0.7582 - val_loss: 0.0477 - val_accuracy: 0.6576
# Epoch 17/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0333 - accuracy: 0.7675 - val_loss: 0.0472 - val_accuracy: 0.6589
# Epoch 18/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0320 - accuracy: 0.7759 - val_loss: 0.0464 - val_accuracy: 0.6704
# Epoch 19/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0310 - accuracy: 0.7850 - val_loss: 0.0474 - val_accuracy: 0.6683
# Epoch 20/100
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0298 - accuracy: 0.7929 - val_loss: 0.0470 - val_accuracy: 0.6699
# Epoch 21/100
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0291 - accuracy: 0.7994 - val_loss: 0.0464 - val_accuracy: 0.6737
# Epoch 22/100
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0287 - accuracy: 0.8025 - val_loss: 0.0468 - val_accuracy: 0.6751
# Epoch 23/100
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0276 - accuracy: 0.8090 - val_loss: 0.0476 - val_accuracy: 0.6658
# Epoch 24/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0273 - accuracy: 0.8132 - val_loss: 0.0461 - val_accuracy: 0.6731
# Epoch 25/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0268 - accuracy: 0.8170 - val_loss: 0.0468 - val_accuracy: 0.6755
# Epoch 26/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0258 - accuracy: 0.8245 - val_loss: 0.0484 - val_accuracy: 0.6719
# Epoch 27/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0256 - accuracy: 0.8266 - val_loss: 0.0476 - val_accuracy: 0.6667
# Epoch 28/100
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0246 - accuracy: 0.8345 - val_loss: 0.0474 - val_accuracy: 0.6782
# Epoch 29/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0241 - accuracy: 0.8372 - val_loss: 0.0480 - val_accuracy: 0.6722
# Epoch 30/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0229 - accuracy: 0.8465 - val_loss: 0.0480 - val_accuracy: 0.6779
# Epoch 31/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0235 - accuracy: 0.8417 - val_loss: 0.0485 - val_accuracy: 0.6744
# Epoch 32/100
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0233 - accuracy: 0.8439 - val_loss: 0.0479 - val_accuracy: 0.6719
# Epoch 33/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0224 - accuracy: 0.8509 - val_loss: 0.0487 - val_accuracy: 0.6733
# Epoch 34/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0218 - accuracy: 0.8552 - val_loss: 0.0489 - val_accuracy: 0.6706
# Epoch 35/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0212 - accuracy: 0.8581 - val_loss: 0.0483 - val_accuracy: 0.6769
# Epoch 36/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0211 - accuracy: 0.8603 - val_loss: 0.0487 - val_accuracy: 0.6788
# Epoch 37/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0209 - accuracy: 0.8614 - val_loss: 0.0492 - val_accuracy: 0.6678
# Epoch 38/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0207 - accuracy: 0.8620 - val_loss: 0.0504 - val_accuracy: 0.6633
# Epoch 39/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0197 - accuracy: 0.8692 - val_loss: 0.0495 - val_accuracy: 0.6732
# Epoch 40/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0195 - accuracy: 0.8718 - val_loss: 0.0496 - val_accuracy: 0.6735
# Epoch 41/100
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0196 - accuracy: 0.8718 - val_loss: 0.0503 - val_accuracy: 0.6697
# Epoch 42/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0198 - accuracy: 0.8681 - val_loss: 0.0512 - val_accuracy: 0.6658
# Epoch 43/100
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0187 - accuracy: 0.8771 - val_loss: 0.0506 - val_accuracy: 0.6657
# Epoch 44/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0186 - accuracy: 0.8768 - val_loss: 0.0495 - val_accuracy: 0.6717
# Epoch 45/100
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0184 - accuracy: 0.8793 - val_loss: 0.0490 - val_accuracy: 0.6717
# Epoch 46/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0183 - accuracy: 0.8800 - val_loss: 0.0490 - val_accuracy: 0.6813
# Epoch 47/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0175 - accuracy: 0.8855 - val_loss: 0.0500 - val_accuracy: 0.6747
# Epoch 48/100
# 391/391 [==============================] - 4s 9ms/step - loss: 0.0177 - accuracy: 0.8838 - val_loss: 0.0490 - val_accuracy: 0.6767

# %%
VGG.save("cifar10_VGG.h5")

# %%
# Loss
fig, ax = plt.subplots(figsize=(8,4))
plt.title('loss')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss', linestyle='--')
plt.legend()
plt.show()

# Accuracy
fig, ax = plt.subplots(figsize=(8,4))
plt.title('accuracy')
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy', linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# # ResNet

# %%
from tensorflow import Tensor
from tensorflow.keras.layers import ReLU, BatchNormalization, Add

def relu_bn(inputs: Tensor) -> Tensor:
    relu = ReLU()(inputs)
    bn = BatchNormalization()(relu)
    return bn

def residual_block(x: Tensor, downsample: bool, filters: int, kernel_size: int = 3) -> Tensor:
    y = tf.keras.layers.Conv2D(kernel_size=kernel_size, strides= (1 if not downsample else 2), filters=filters, padding="same")(x)
    y = relu_bn(y)
    y = tf.keras.layers.Conv2D(kernel_size=kernel_size, strides=1, filters=filters, padding="same")(y)

    if downsample:
        x = tf.keras.layers.Conv2D(kernel_size=1, strides=2, filters=filters, padding="same")(x)
    out = Add()([x, y])
    out = relu_bn(out)
    return out


def get_ResNet(input_shape, output_shape):
    
    inputs = tf.keras.Input(shape=input_shape, name='input_layer')
    num_filters = 32

    x = BatchNormalization()(inputs)
    x = tf.keras.layers.Conv2D(num_filters, kernel_size=3, strides=1, padding="same")(x)
    x = relu_bn(x)
    
    num_blocks_list = [2, 5, 2]
    for i in range(len(num_blocks_list)):
      num_blocks = num_blocks_list[i]
      for j in range(num_blocks):
        x = residual_block(x, downsample=(j==0 and i!=0), filters=num_filters)
      num_filters *= 2
    
    x = tf.keras.layers.AveragePooling2D(4)(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(64, activation="relu")(x)
    outputs = tf.keras.layers.Dense(output_shape, activation='softmax')(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="functional_api")

    return model

# %%
ResNet = get_ResNet((32,32,3), 10)
ResNet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss=tf.keras.losses.MSE, metrics=['accuracy'])
ResNet.summary()
# Out:
# Model: "functional_api"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 32, 32, 3)]  0           []
#
#  batch_normalization_50 (BatchN  (None, 32, 32, 3)   12          ['input_layer[0][0]']
#  ormalization)
#
#  conv2d_53 (Conv2D)             (None, 32, 32, 32)   896         ['batch_normalization_50[0][0]']
#
#  re_lu_48 (ReLU)                (None, 32, 32, 32)   0           ['conv2d_53[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 32, 32, 32)  128         ['re_lu_48[0][0]']
#  ormalization)
#
#  conv2d_54 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_51[0][0]']
#
#  re_lu_49 (ReLU)                (None, 32, 32, 32)   0           ['conv2d_54[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 32, 32, 32)  128         ['re_lu_49[0][0]']
#  ormalization)
#
#  conv2d_55 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_52[0][0]']
#
#  add_23 (Add)                   (None, 32, 32, 32)   0           ['batch_normalization_51[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  re_lu_50 (ReLU)                (None, 32, 32, 32)   0           ['add_23[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 32, 32, 32)  128         ['re_lu_50[0][0]']
#  ormalization)
#
#  conv2d_56 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_53[0][0]']
#
#  re_lu_51 (ReLU)                (None, 32, 32, 32)   0           ['conv2d_56[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 32, 32, 32)  128         ['re_lu_51[0][0]']
#  ormalization)
#
#  conv2d_57 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_54[0][0]']
#
#  add_24 (Add)                   (None, 32, 32, 32)   0           ['batch_normalization_53[0][0]',
#                                                                   'conv2d_57[0][0]']
#
#  re_lu_52 (ReLU)                (None, 32, 32, 32)   0           ['add_24[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 32, 32, 32)  128         ['re_lu_52[0][0]']
#  ormalization)
#
#  conv2d_58 (Conv2D)             (None, 16, 16, 64)   18496       ['batch_normalization_55[0][0]']
#
#  re_lu_53 (ReLU)                (None, 16, 16, 64)   0           ['conv2d_58[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 16, 16, 64)  256         ['re_lu_53[0][0]']
#  ormalization)
#
#  conv2d_60 (Conv2D)             (None, 16, 16, 64)   2112        ['batch_normalization_55[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 16, 16, 64)   36928       ['batch_normalization_56[0][0]']
#
#  add_25 (Add)                   (None, 16, 16, 64)   0           ['conv2d_60[0][0]',
#                                                                   'conv2d_59[0][0]']
#
#  re_lu_54 (ReLU)                (None, 16, 16, 64)   0           ['add_25[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 16, 16, 64)  256         ['re_lu_54[0][0]']
#  ormalization)
#
#  conv2d_61 (Conv2D)             (None, 16, 16, 64)   36928       ['batch_normalization_57[0][0]']
#
#  re_lu_55 (ReLU)                (None, 16, 16, 64)   0           ['conv2d_61[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 16, 16, 64)  256         ['re_lu_55[0][0]']
#  ormalization)
#
#  conv2d_62 (Conv2D)             (None, 16, 16, 64)   36928       ['batch_normalization_58[0][0]']
#
#  add_26 (Add)                   (None, 16, 16, 64)   0           ['batch_normalization_57[0][0]',
#                                                                   'conv2d_62[0][0]']
#
#  re_lu_56 (ReLU)                (None, 16, 16, 64)   0           ['add_26[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 16, 16, 64)  256         ['re_lu_56[0][0]']
#  ormalization)
#
#  conv2d_63 (Conv2D)             (None, 16, 16, 64)   36928       ['batch_normalization_59[0][0]']
#
#  re_lu_57 (ReLU)                (None, 16, 16, 64)   0           ['conv2d_63[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 16, 16, 64)  256         ['re_lu_57[0][0]']
#  ormalization)
#
#  conv2d_64 (Conv2D)             (None, 16, 16, 64)   36928       ['batch_normalization_60[0][0]']
#
#  add_27 (Add)                   (None, 16, 16, 64)   0           ['batch_normalization_59[0][0]',
#                                                                   'conv2d_64[0][0]']
#
#  re_lu_58 (ReLU)                (None, 16, 16, 64)   0           ['add_27[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 16, 16, 64)  256         ['re_lu_58[0][0]']
#  ormalization)
#
#  conv2d_65 (Conv2D)             (None, 16, 16, 64)   36928       ['batch_normalization_61[0][0]']
#
#  re_lu_59 (ReLU)                (None, 16, 16, 64)   0           ['conv2d_65[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 16, 16, 64)  256         ['re_lu_59[0][0]']
#  ormalization)
#
#  conv2d_66 (Conv2D)             (None, 16, 16, 64)   36928       ['batch_normalization_62[0][0]']
#
#  add_28 (Add)                   (None, 16, 16, 64)   0           ['batch_normalization_61[0][0]',
#                                                                   'conv2d_66[0][0]']
#
#  re_lu_60 (ReLU)                (None, 16, 16, 64)   0           ['add_28[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 16, 16, 64)  256         ['re_lu_60[0][0]']
#  ormalization)
#
#  conv2d_67 (Conv2D)             (None, 16, 16, 64)   36928       ['batch_normalization_63[0][0]']
#
#  re_lu_61 (ReLU)                (None, 16, 16, 64)   0           ['conv2d_67[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 16, 16, 64)  256         ['re_lu_61[0][0]']
#  ormalization)
#
#  conv2d_68 (Conv2D)             (None, 16, 16, 64)   36928       ['batch_normalization_64[0][0]']
#
#  add_29 (Add)                   (None, 16, 16, 64)   0           ['batch_normalization_63[0][0]',
#                                                                   'conv2d_68[0][0]']
#
#  re_lu_62 (ReLU)                (None, 16, 16, 64)   0           ['add_29[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 16, 16, 64)  256         ['re_lu_62[0][0]']
#  ormalization)
#
#  conv2d_69 (Conv2D)             (None, 8, 8, 128)    73856       ['batch_normalization_65[0][0]']
#
#  re_lu_63 (ReLU)                (None, 8, 8, 128)    0           ['conv2d_69[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 8, 8, 128)   512         ['re_lu_63[0][0]']
#  ormalization)
#
#  conv2d_71 (Conv2D)             (None, 8, 8, 128)    8320        ['batch_normalization_65[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 8, 8, 128)    147584      ['batch_normalization_66[0][0]']
#
#  add_30 (Add)                   (None, 8, 8, 128)    0           ['conv2d_71[0][0]',
#                                                                   'conv2d_70[0][0]']
#
#  re_lu_64 (ReLU)                (None, 8, 8, 128)    0           ['add_30[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 8, 8, 128)   512         ['re_lu_64[0][0]']
#  ormalization)
#
#  conv2d_72 (Conv2D)             (None, 8, 8, 128)    147584      ['batch_normalization_67[0][0]']
#
#  re_lu_65 (ReLU)                (None, 8, 8, 128)    0           ['conv2d_72[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 8, 8, 128)   512         ['re_lu_65[0][0]']
#  ormalization)
#
#  conv2d_73 (Conv2D)             (None, 8, 8, 128)    147584      ['batch_normalization_68[0][0]']
#
#  add_31 (Add)                   (None, 8, 8, 128)    0           ['batch_normalization_67[0][0]',
#                                                                   'conv2d_73[0][0]']
#
#  re_lu_66 (ReLU)                (None, 8, 8, 128)    0           ['add_31[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 8, 8, 128)   512         ['re_lu_66[0][0]']
#  ormalization)
#
#  average_pooling2d_2 (AveragePo  (None, 2, 2, 128)   0           ['batch_normalization_69[0][0]']
#  oling2D)
#
#  flatten_2 (Flatten)            (None, 512)          0           ['average_pooling2d_2[0][0]']
#
#  dense_4 (Dense)                (None, 64)           32832       ['flatten_2[0][0]']
#
#  dense_5 (Dense)                (None, 10)           650         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 954,518
# Trainable params: 951,888
# Non-trainable params: 2,630
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(ResNet, to_file="my_model.png", show_shapes=True)

# %%
history = ResNet.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    batch_size=128,
    epochs=30,
    callbacks=[early_stopping], # put your callbacks in a list
)
# Out:
# Epoch 1/30
# 391/391 [==============================] - 31s 54ms/step - loss: 0.0614 - accuracy: 0.5134 - val_loss: 0.0509 - val_accuracy: 0.6169
# Epoch 2/30
# 391/391 [==============================] - 20s 52ms/step - loss: 0.0412 - accuracy: 0.6960 - val_loss: 0.0458 - val_accuracy: 0.6693
# Epoch 3/30
# 391/391 [==============================] - 20s 52ms/step - loss: 0.0326 - accuracy: 0.7652 - val_loss: 0.0362 - val_accuracy: 0.7430
# Epoch 4/30
# 391/391 [==============================] - 21s 53ms/step - loss: 0.0278 - accuracy: 0.8030 - val_loss: 0.0361 - val_accuracy: 0.7494
# Epoch 5/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0236 - accuracy: 0.8348 - val_loss: 0.0331 - val_accuracy: 0.7667
# Epoch 6/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0203 - accuracy: 0.8590 - val_loss: 0.0282 - val_accuracy: 0.8027
# Epoch 7/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0176 - accuracy: 0.8795 - val_loss: 0.0264 - val_accuracy: 0.8173
# Epoch 8/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0155 - accuracy: 0.8942 - val_loss: 0.0290 - val_accuracy: 0.8010
# Epoch 9/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0135 - accuracy: 0.9099 - val_loss: 0.0273 - val_accuracy: 0.8146
# Epoch 10/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0115 - accuracy: 0.9239 - val_loss: 0.0272 - val_accuracy: 0.8167
# Epoch 11/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0101 - accuracy: 0.9344 - val_loss: 0.0275 - val_accuracy: 0.8178
# Epoch 12/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0091 - accuracy: 0.9401 - val_loss: 0.0278 - val_accuracy: 0.8158
# Epoch 13/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0080 - accuracy: 0.9475 - val_loss: 0.0273 - val_accuracy: 0.8209
# Epoch 14/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0072 - accuracy: 0.9532 - val_loss: 0.0281 - val_accuracy: 0.8154
# Epoch 15/30
# 391/391 [==============================] - 21s 55ms/step - loss: 0.0065 - accuracy: 0.9585 - val_loss: 0.0288 - val_accuracy: 0.8141
# Epoch 16/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0056 - accuracy: 0.9639 - val_loss: 0.0267 - val_accuracy: 0.8271
# Epoch 17/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0057 - accuracy: 0.9635 - val_loss: 0.0268 - val_accuracy: 0.8265
# Epoch 18/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0049 - accuracy: 0.9685 - val_loss: 0.0270 - val_accuracy: 0.8271
# Epoch 19/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0052 - accuracy: 0.9665 - val_loss: 0.0282 - val_accuracy: 0.8197
# Epoch 20/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0043 - accuracy: 0.9727 - val_loss: 0.0264 - val_accuracy: 0.8362
# Epoch 21/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0042 - accuracy: 0.9731 - val_loss: 0.0278 - val_accuracy: 0.8268
# Epoch 22/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0044 - accuracy: 0.9722 - val_loss: 0.0268 - val_accuracy: 0.8345
# Epoch 23/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0037 - accuracy: 0.9769 - val_loss: 0.0275 - val_accuracy: 0.8293
# Epoch 24/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0037 - accuracy: 0.9768 - val_loss: 0.0273 - val_accuracy: 0.8299
# Epoch 25/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0038 - accuracy: 0.9755 - val_loss: 0.0279 - val_accuracy: 0.8273
# Epoch 26/30
# 391/391 [==============================] - 21s 55ms/step - loss: 0.0035 - accuracy: 0.9776 - val_loss: 0.0269 - val_accuracy: 0.8353
# Epoch 27/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0037 - accuracy: 0.9765 - val_loss: 0.0271 - val_accuracy: 0.8300
# Epoch 28/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0032 - accuracy: 0.9799 - val_loss: 0.0269 - val_accuracy: 0.8331
# Epoch 29/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0030 - accuracy: 0.9817 - val_loss: 0.0281 - val_accuracy: 0.8274
# Epoch 30/30
# 391/391 [==============================] - 21s 54ms/step - loss: 0.0031 - accuracy: 0.9804 - val_loss: 0.0281 - val_accuracy: 0.8269

# %%
ResNet.save("/content/drive/MyDrive/Colab Notebooks/Cifar-10 /cifar10_ResNet_f=32.h5")

# %%
# Loss
fig, ax = plt.subplots(figsize=(8,4))
plt.title('loss')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss', linestyle='--')
plt.legend()
plt.show()

# Accuracy
fig, ax = plt.subplots(figsize=(8,4))
plt.title('accuracy')
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy', linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# # kaggle predict

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/Colab Notebooks
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Cifar-10 /test_data'

kaggle_x = []
kaggle_id = []
for i in range(1,201,1):
  kaggle_id.append(str(i)+'.jpg')
  img = cv2.imread(path+'/'+str(i)+'.jpg')
  kaggle_x.append(img)
kaggle_x = np.array(kaggle_x) 
print(kaggle_x.shape)
# Out:
# (200, 32, 32, 3)

# %%
model = tf.keras.models.load_model("/content/drive/MyDrive/Colab Notebooks/Cifar-10 /cifar10_ResNet_f=32.h5")

# %%
predict = model.predict(kaggle_x)
predict = np.argmax(predict, axis=1)
print(predict)
# Out:
# 7/7 [==============================] - 1s 25ms/step
# [2 0 9 9 5 3 1 2 9 4 2 0 5 3 1 6 3 9 1 9 3 5 8 8 2 4 0 6 9 3 5 4 0 5 1 0 9
#  6 9 5 8 2 9 7 9 4 2 3 2 8 0 0 5 9 4 5 2 8 2 9 8 9 2 9 0 7 5 0 8 5 3 7 8 1
#  8 3 0 7 8 9 8 2 8 3 4 0 5 8 1 4 9 4 0 2 1 9 7 8 0 7 8 0 0 1 4 9 8 0 0 0 9
#  4 4 2 5 0 9 0 0 3 4 2 4 3 7 2 7 0 5 6 2 4 0 0 4 0 2 5 4 5 2 6 3 1 0 9 8 9
#  8 2 1 8 0 9 6 6 8 1 0 2 4 7 3 5 2 3 0 8 1 8 8 4 6 6 0 2 5 0 0 1 2 8 1 5 0
#  5 0 1 4 9 3 8 2 2 4 7 6 8 4 2]

# %%
test_label = pd.DataFrame()
test_label["image_id"] = kaggle_id
test_label["class"] = predict
test_label.to_csv('NN_HW5_ResNet_3.csv', index=False)

# %%
import random
import matplotlib.image as img

trans_ans = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck',]
random = random.sample(range(0,200,1),12)

for i in range(0,12,1):
  plt.subplot(3,4,i+1)
  plt.title(trans_ans[predict[random[i]]])
  image = img.imread(path+'/'+str(random[i]+1)+'.jpg')
  plt.imshow(image,alpha=2)
plt.tight_layout()
plt.show()
